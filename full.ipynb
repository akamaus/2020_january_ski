# %%
# %load_ext autoreload
# %autoreload 2

# %%
import planner.food as F
import planner.equipment as E
import planner.utils as U

from members import *
# Out:
# ['Артемьев', 'Вьяль', 'Карпова', 'Кищенко', 'Лаврищева', 'Лебедев', 'Ляшун', 'Миронов', 'Пименов', 'Ткачева', 'Шичанин']
# Количество участников: 11
# Среди них женщин: 3

# %% [markdown]
# # Расчет еды

# %%
import products as P
food_table = F.food_planning(P.Food, 
                             NBreakfast=P.NBreakfast, 
                             NDinner=P.NDinner, 
                             NLunch=P.NLunch, 
                             NSnack=P.NSnack)

food_table
# Out:
# Общий вес: 29128.000000
# Распределенный вес: 29128.000000
# Средний вес на мужчину: 2788.5
# Средний вес на женщину: 2273.3
# Вес на человека в день: 706.1
#
# *** Перевес по еде:
# Вьяль        -2788
# Шичанин      -1964
# Миронов      1458
# Лебедев      1260
# Ткачева      1256
# Пименов      952
# Ляшун        776
# Лаврищева    -680
# Артемьев     402
# Карпова      244
# Кищенко      -94
#
# Остаток: 0.0
#                      product  portion  times  weight  Кто несет
# 0               Рис(завтрак)    770.0    1.0   770.0    Пименов
# 1            Гречка(завтрак)    770.0    1.0   770.0    Пименов
# 2          Спагетти(завтрак)    935.0    1.0   935.0    Пименов
# 3   Сливочное масло(завтрак)    165.0    1.0   165.0    Шичанин
# 4      Сухое молоко(завтрак)    220.0    2.0   440.0    Шичанин
# 5               Сыр(завтрак)    605.0    3.0  1815.0    Кищенко
# 6                  Рис(ужин)    990.0    1.0   990.0    Миронов
# 7               Гречка(ужин)    990.0    2.0  1980.0    Миронов
# 8             Спагетти(ужин)   1100.0    1.0  1100.0    Миронов
# 9              Тушенка(ужин)    891.0    4.0  3564.0      Ляшун
# 10            Сладости(ужин)    660.0    2.0  1320.0   Артемьев
# 11            Сладости(ужин)    660.0    2.0  1320.0  Лаврищева
# 12              Лимоны(ужин)    165.0    4.0   660.0    Лебедев
# 13               Спирт(ужин)    132.0    4.0   528.0    Лебедев
# 14          Колбаса(перекус)    385.0    1.0   385.0    Пименов
# 15         Грудинка(перекус)    385.0    1.0   385.0   Артемьев
# 16              Сыр(перекус)    385.0    1.0   385.0   Артемьев
# 17             Сало(перекус)    220.0    1.0   220.0   Артемьев
# 18          конфеты(перекус)    440.0    2.0   880.0   Артемьев
# 19          конфеты(перекус)    440.0    2.0   880.0    Кищенко
# 20            Вафли(перекус)    220.0    4.0   880.0    Пименов
# 21                    Сухари    440.0    4.0  1760.0    Карпова
# 22                      Соль     77.0    4.0   308.0    Ткачева
# 23                     Сахар    770.0    2.0  1540.0    Лебедев
# 24                     Сахар    770.0    2.0  1540.0    Ткачева
# 25                       Чай     77.0    4.0   308.0    Лебедев
# 26                      Кофе     33.0    4.0   132.0    Лебедев
# 27                       Лук    121.0    4.0   484.0    Карпова
# 28                    Чеснок     44.0    4.0   176.0    Миронов
# 29                     Перец     11.0    4.0    44.0    Шичанин
# 30              Хмели-сунели     11.0    4.0    44.0    Шичанин
# 31                    Аджика     33.0    4.0   132.0    Шичанин
# 32                  Шиповник    352.0    4.0  1408.0    Ткачева
# 33          Сухофрукты+орехи    220.0    4.0   880.0    Лебедев

# %% [markdown]
# ## Таблица поручений по закупке еды

# %%
U.print_grouped_by_members(food_table, fname='food.txt')
# Out:
# Участник: Артемьев, несет: 3190.0
#               product  portion  times  weight Кто несет
# 10     Сладости(ужин)    660.0    2.0  1320.0  Артемьев
# 15  Грудинка(перекус)    385.0    1.0   385.0  Артемьев
# 16       Сыр(перекус)    385.0    1.0   385.0  Артемьев
# 17      Сало(перекус)    220.0    1.0   220.0  Артемьев
# 18   конфеты(перекус)    440.0    2.0   880.0  Артемьев
#
#
#
# Участник: Карпова, несет: 2244.0
#    product  portion  times  weight Кто несет
# 21  Сухари    440.0    4.0  1760.0   Карпова
# 26     Лук    121.0    4.0   484.0   Карпова
#
#
#
# Участник: Кищенко, несет: 2695.0
#              product  portion  times  weight Кто несет
# 5       Сыр(завтрак)    605.0    3.0  1815.0   Кищенко
# 19  конфеты(перекус)    440.0    2.0   880.0   Кищенко
#
#
#
# Участник: Лаврищева, несет: 1320.0
#            product  portion  times  weight  Кто несет
# 11  Сладости(ужин)    660.0    2.0  1320.0  Лаврищева
#
#
#
# Участник: Лебедев, несет: 4048.0
#              product  portion  times  weight Кто несет
# 12      Лимоны(ужин)    165.0    4.0   660.0   Лебедев
# 13       Спирт(ужин)    165.0    4.0   660.0   Лебедев
# 23             Сахар    770.0    2.0  1540.0   Лебедев
# 25               Чай     77.0    4.0   308.0   Лебедев
# 32  Сухофрукты+орехи    220.0    4.0   880.0   Лебедев
#
#
#
# Участник: Ляшун, несет: 3564.0
#          product  portion  times  weight Кто несет
# 9  Тушенка(ужин)    891.0    4.0  3564.0     Ляшун
#
#
#
# Участник: Миронов, несет: 4246.0
#            product  portion  times  weight Кто несет
# 6        Рис(ужин)    990.0    1.0   990.0   Миронов
# 7     Гречка(ужин)    990.0    2.0  1980.0   Миронов
# 8   Спагетти(ужин)   1100.0    1.0  1100.0   Миронов
# 27          Чеснок     44.0    4.0   176.0   Миронов
#
#
#
# Участник: Пименов, несет: 3740.0
#               product  portion  times  weight Кто несет
# 0        Рис(завтрак)    770.0    1.0   770.0   Пименов
# 1     Гречка(завтрак)    770.0    1.0   770.0   Пименов
# 2   Спагетти(завтрак)    935.0    1.0   935.0   Пименов
# 14   Колбаса(перекус)    385.0    1.0   385.0   Пименов
# 20     Вафли(перекус)    220.0    4.0   880.0   Пименов
#
#
#
# Участник: Ткачева, несет: 3256.0
#      product  portion  times  weight Кто несет
# 22      Соль     77.0    4.0   308.0   Ткачева
# 24     Сахар    770.0    2.0  1540.0   Ткачева
# 31  Шиповник    352.0    4.0  1408.0   Ткачева
#
#
#
# Участник: Шичанин, несет: 825.0
#                      product  portion  times  weight Кто несет
# 3   Сливочное масло(завтрак)    165.0    1.0   165.0   Шичанин
# 4      Сухое молоко(завтрак)    220.0    2.0   440.0   Шичанин
# 28                     Перец     11.0    4.0    44.0   Шичанин
# 29              Хмели-сунели     11.0    4.0    44.0   Шичанин
# 30                    Аджика     33.0    4.0   132.0   Шичанин

# %% [markdown]
# # Снаряжение

# %%
import stuff as S
stuff_table = E.equipment_planning(S.SharedEquipment); stuff_table
# Out:
# Общий вес: 40310
# Средний вес на мужчину: 4039
# Средний вес на женщину: 733
#
#
# *** Перевес по снаряжению:
# Артемьев     -4039
# Ляшун        -3549
# Шичанин      3461
# Вьяль        2891
# Пименов      1951
# Карпова      -1000
# Миронов      -939
# Лаврищева    500
# Ткачева      -300
# Кищенко      161
# Лебедев      61
#
# Остаток: 5800
#                       equipment  weight  Кто несет
# 0             Палатка (в чехле)  7500.0    Шичанин
# 1              Подставка под ЦК   200.0    Ткачева
# 2    Тент для палатки (в чехле)  2000.0    Миронов
# 3       Спальник внутренний 4ка  4200.0    Кищенко
# 4                  Спальник 4ка  3800.0    Пименов
# 5        Печка + крышка от кана  3100.0    Лебедев
# 6             Квадрат для трубы   200.0    Лебедев
# 7                 Каны с трубой  2900.0      Вьяль
# 8                   Сухой спирт   120.0      Вьяль
# 9                      Половник    50.0      Вьяль
# 10                      Мочалка    20.0      Вьяль
# 11                        Веник   170.0    Пименов
# 12                    Лопата №1   490.0      Ляшун
# 13                     Топор №1  1100.0    Миронов
# 14               Пила двуручная  1120.0    Пименов
# 15                Пила лучковая   800.0      Вьяль
# 16                 Термос №1 1л   600.0    Лебедев
# 17              Термос N2 1.25л   900.0    Пименов
# 18                     Ремнабор  2500.0      Вьяль
# 19                       Аптека  1500.0  Лаврищева
# 20                         GPS1   100.0    Лебедев
# 21           4 батареек для GPS   100.0    Лебедев
# 22             Карты, документы   200.0      Вьяль
# 23                    Планшетка   280.0      Вьяль
# 24                       Компас    30.0      Вьяль
# 25                Часы наручные    30.0      Вьяль
# 26  Веревка(шнурок) (D=4мм) 50м   500.0    Ткачева

# %% [markdown]
# ### Распределение снаряжения

# %%
U.print_grouped_by_members(stuff_table, fname='stuff.txt')
# Out:
# Участник: Вьяль, несет: 6930.0
#            equipment  weight Кто несет
# 7      Каны с трубой  2900.0     Вьяль
# 8        Сухой спирт   120.0     Вьяль
# 9           Половник    50.0     Вьяль
# 10           Мочалка    20.0     Вьяль
# 15     Пила лучковая   800.0     Вьяль
# 18          Ремнабор  2500.0     Вьяль
# 22  Карты, документы   200.0     Вьяль
# 23         Планшетка   280.0     Вьяль
# 24            Компас    30.0     Вьяль
# 25     Часы наручные    30.0     Вьяль
#
#
#
# Участник: Кищенко, несет: 4200.0
#                  equipment  weight Кто несет
# 3  Спальник внутренний 4ка  4200.0   Кищенко
#
#
#
# Участник: Лаврищева, несет: 1500.0
#    equipment  weight  Кто несет
# 19    Аптека  1500.0  Лаврищева
#
#
#
# Участник: Лебедев, несет: 4100.0
#                  equipment  weight Кто несет
# 5   Печка + крышка от кана  3100.0   Лебедев
# 6        Квадрат для трубы   200.0   Лебедев
# 16            Термос №1 1л   600.0   Лебедев
# 20                    GPS1   100.0   Лебедев
# 21      4 батареек для GPS   100.0   Лебедев
#
#
#
# Участник: Ляшун, несет: 490.0
#     equipment  weight Кто несет
# 12  Лопата №1   490.0     Ляшун
#
#
#
# Участник: Миронов, несет: 3100.0
#                      equipment  weight Кто несет
# 2   Тент для палатки (в чехле)  2000.0   Миронов
# 13                    Топор №1  1100.0   Миронов
#
#
#
# Участник: Пименов, несет: 5990.0
#           equipment  weight Кто несет
# 4      Спальник 4ка  3800.0   Пименов
# 11            Веник   170.0   Пименов
# 14   Пила двуручная  1120.0   Пименов
# 17  Термос N2 1.25л   900.0   Пименов
#
#
#
# Участник: Ткачева, несет: 700.0
#                       equipment  weight Кто несет
# 1              Подставка под ЦК   200.0   Ткачева
# 26  Веревка(шнурок) (D=4мм) 50м   500.0   Ткачева
#
#
#
# Участник: Шичанин, несет: 7500.0
#            equipment  weight Кто несет
# 0  Палатка (в чехле)  7500.0   Шичанин

# %% [markdown]
# # Общий баланс веса

# %%
import numpy as np
avg_men_weight = np.mean([m.food_weight() + m.equipment_weight() for m in Members.values() if m.male])

# %%
U.print_overweight(Members, lambda m: m.food_weight() + m.equipment_weight(), 
                   avg_men_weight, 
                   WomanFoodWeightNorm + WomanSharedEquipWeightNorm );
# Out:
# *** Перевес:
# Артемьев     -3637
# Пименов      2903
# Ляшун        -2773
# Шичанин      1498
# Лебедев      1321
# Ткачева      956
# Карпова      -756
# Миронов      519
# Лаврищева    -180
# Вьяль        103
# Кищенко      68

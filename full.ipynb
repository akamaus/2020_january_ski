# %%
# %load_ext autoreload
# %autoreload 2

# %%
import planner.food as F
import planner.equipment as E
import planner.utils as U

from members import *
# Out:
# ['Артемьев', 'Вьяль', 'Кищенко', 'Лаврищева', 'Лебедев', 'Ляшун', 'Миронов', 'Пименов', 'Ткачева', 'Шичанин']
# Количество участников: 10
# Среди них женщин: 2

# %% [markdown]
# # Расчет еды

# %%
import products as P
food_table = F.food_planning(P.Food, 
                             NBreakfast=P.NBreakfast, 
                             NDinner=P.NDinner, 
                             NLunch=P.NLunch, 
                             NSnack=P.NSnack)

food_table
# Out:
# Общий вес: 28860.000000
# Распределенный вес: 28830.000000
# Средний вес на мужчину: 3152.5
# Средний вес на женщину: 1805.0
# Вес на человека в день: 824.6
#
# *** Перевес по еде:
# Пименов          0 -3152
# Шичанин       6090 2938
# Вьяль         2000 -1152
# Миронов       3960 808
# Кищенко       3550 398
# Лаврищева     1800 -200
# Ткачева       1810 -190
# Лебедев       3290 138
# Ляшун         3280 128
# Артемьев      3050 -102
#
# Остаток: 30.0
#                      product  portion  times  weight  Кто несет
# 0          Геркулес(завтрак)    700.0   1.00   700.0    Миронов
# 1            Гречка(завтрак)    700.0   1.00   700.0    Миронов
# 2             Пшено(завтрак)    700.0   1.00   700.0    Кищенко
# 3      Сухое молоко(завтрак)    250.0   3.00   750.0    Кищенко
# 4   Сливочное масло(завтрак)    150.0   2.00   300.0    Кищенко
# 5                       Изюм    300.0   1.00   300.0    Кищенко
# 6                      Тыква    200.0   1.00   200.0    Шичанин
# 7                  Чернослив    200.0   1.00   200.0    Шичанин
# 8               Сыр(завтрак)    500.0   3.00  1500.0    Кищенко
# 9                  Рис(ужин)    800.0   1.00   800.0   Артемьев
# 10              Гречка(ужин)    800.0   1.00   800.0   Артемьев
# 11            Сладости(ужин)    400.0   2.00   800.0    Миронов
# 12             Козинак(ужин)    500.0   1.00   500.0    Шичанин
# 13          Кисель фруктовый    400.0   1.00   400.0    Шичанин
# 14               Спирт(ужин)    120.0   3.00   360.0    Лебедев
# 15                Мясо(ужин)    700.0   3.00  2100.0    Шичанин
# 16    Козинак(перед поездом)    500.0   1.00   500.0    Шичанин
# 17        Сыр(перед поездом)    400.0   1.00   400.0   Артемьев
# 18                  Картошка   3000.0   0.15   450.0    Лебедев
# 19                  Картошка   3000.0   0.51  1530.0    Ткачева
# 20                  Картошка   3000.0   0.33   990.0    Шичанин
# 21                  Картошка   3000.0   0.01    30.0        NaN
# 22                   Морковь    500.0   1.00   500.0    Шичанин
# 23                Лук+специи    200.0   1.00   200.0    Шичанин
# 24         Грудинка(перекус)    400.0   1.00   400.0    Миронов
# 25          Колбаса(перекус)    400.0   1.00   400.0    Миронов
# 26             Сало(перекус)    400.0   1.00   400.0    Миронов
# 27              Сыр(перекус)    400.0   1.00   400.0    Миронов
# 28          Козинак(перекус)    500.0   1.00   500.0    Шичанин
# 29    конфеты+вафли(перекус)    600.0   3.00  1800.0  Лаврищева
# 30            Орехи(перекус)    350.0   3.00  1050.0   Артемьев
# 31                    Сухари    400.0   4.00  1600.0    Лебедев
# 32                      Соль     70.0   4.00   280.0    Ткачева
# 33                     Сахар    500.0   4.00  2000.0      Ляшун
# 34                      Кофе     50.0   4.00   200.0    Лебедев
# 35                       Чай     70.0   4.00   280.0    Лебедев
# 36                    Чеснок     40.0   4.00   160.0    Миронов
# 37                     Перец     10.0   4.00    40.0    Лебедев
# 38              Хмели-сунели     10.0   4.00    40.0    Лебедев
# 39                    Аджика     30.0   4.00   120.0    Лебедев
# 40             Другие специи     50.0   4.00   200.0    Лебедев
# 41      Сухофрукты(в термос)    300.0   4.00  1200.0      Вьяль
# 42        Шиповник(в термос)    320.0   4.00  1280.0      Ляшун
# 43           Лимоны в сахаре    200.0   4.00   800.0      Вьяль

# %% [markdown]
# ## Таблица поручений по закупке еды

# %%
U.print_grouped_by_members(food_table, fname='food.txt')
# Out:
# Участник: Артемьев, несет: 3050.0
#                product  portion  times  weight Кто несет
# 9            Рис(ужин)    800.0    1.0   800.0  Артемьев
# 10        Гречка(ужин)    800.0    1.0   800.0  Артемьев
# 17  Сыр(перед поездом)    400.0    1.0   400.0  Артемьев
# 30      Орехи(перекус)    350.0    3.0  1050.0  Артемьев
#
#
#
# Участник: Вьяль, несет: 2000.0
#                  product  portion  times  weight Кто несет
# 41  Сухофрукты(в термос)    300.0    4.0  1200.0     Вьяль
# 43       Лимоны в сахаре    200.0    4.0   800.0     Вьяль
#
#
#
# Участник: Кищенко, несет: 3550.0
#                     product  portion  times  weight Кто несет
# 2            Пшено(завтрак)    700.0    1.0   700.0   Кищенко
# 3     Сухое молоко(завтрак)    250.0    3.0   750.0   Кищенко
# 4  Сливочное масло(завтрак)    150.0    2.0   300.0   Кищенко
# 5                      Изюм    300.0    1.0   300.0   Кищенко
# 8              Сыр(завтрак)    500.0    3.0  1500.0   Кищенко
#
#
#
# Участник: Лаврищева, несет: 1800.0
#                    product  portion  times  weight  Кто несет
# 29  конфеты+вафли(перекус)    600.0    3.0  1800.0  Лаврищева
#
#
#
# Участник: Лебедев, несет: 3290.0
#           product  portion  times  weight Кто несет
# 14    Спирт(ужин)    120.0   3.00   360.0   Лебедев
# 18       Картошка   3000.0   0.15   450.0   Лебедев
# 31         Сухари    400.0   4.00  1600.0   Лебедев
# 34           Кофе     50.0   4.00   200.0   Лебедев
# 35            Чай     70.0   4.00   280.0   Лебедев
# 37          Перец     10.0   4.00    40.0   Лебедев
# 38   Хмели-сунели     10.0   4.00    40.0   Лебедев
# 39         Аджика     30.0   4.00   120.0   Лебедев
# 40  Другие специи     50.0   4.00   200.0   Лебедев
#
#
#
# Участник: Ляшун, несет: 3280.0
#                product  portion  times  weight Кто несет
# 33               Сахар    500.0    4.0  2000.0     Ляшун
# 42  Шиповник(в термос)    320.0    4.0  1280.0     Ляшун
#
#
#
# Участник: Миронов, несет: 3960.0
#               product  portion  times  weight Кто несет
# 0   Геркулес(завтрак)    700.0    1.0   700.0   Миронов
# 1     Гречка(завтрак)    700.0    1.0   700.0   Миронов
# 11     Сладости(ужин)    400.0    2.0   800.0   Миронов
# 24  Грудинка(перекус)    400.0    1.0   400.0   Миронов
# 25   Колбаса(перекус)    400.0    1.0   400.0   Миронов
# 26      Сало(перекус)    400.0    1.0   400.0   Миронов
# 27       Сыр(перекус)    400.0    1.0   400.0   Миронов
# 36             Чеснок     40.0    4.0   160.0   Миронов
#
#
#
# Участник: Ткачева, несет: 1810.0
#      product  portion  times  weight Кто несет
# 19  Картошка   3000.0   0.51  1530.0   Ткачева
# 32      Соль     70.0   4.00   280.0   Ткачева
#
#
#
# Участник: Шичанин, несет: 6090.0
#                    product  portion  times  weight Кто несет
# 6                    Тыква    200.0   1.00   200.0   Шичанин
# 7                Чернослив    200.0   1.00   200.0   Шичанин
# 12           Козинак(ужин)    500.0   1.00   500.0   Шичанин
# 13        Кисель фруктовый    400.0   1.00   400.0   Шичанин
# 15              Мясо(ужин)    700.0   3.00  2100.0   Шичанин
# 16  Козинак(перед поездом)    500.0   1.00   500.0   Шичанин
# 20                Картошка   3000.0   0.33   990.0   Шичанин
# 22                 Морковь    500.0   1.00   500.0   Шичанин
# 23              Лук+специи    200.0   1.00   200.0   Шичанин
# 28        Козинак(перекус)    500.0   1.00   500.0   Шичанин

# %% [markdown]
# # Снаряжение

# %%
import stuff as S
stuff_table = E.equipment_planning(S.SharedEquipment); stuff_table
# Out:
# Общий вес: 40110
# Средний вес на мужчину: 4752
# Средний вес на женщину: 1045
#
#
# *** Перевес по снаряжению:
# Пименов       7500 2748
# Шичанин       2220 -2532
# Вьяль         6140 1388
# Миронов       3900 -852
# Кищенко       4200 -552
# Ляшун         4560 -192
# Лебедев       4600 -152
# Артемьев      4900 148
# Лаврищева     1100 100
# Ткачева        990 -10
#
# Остаток: 0
#                       equipment  weight  Кто несет
# 0             Палатка (в чехле)  7500.0    Пименов
# 1              Подставка под ЦК   200.0    Ткачева
# 2    Тент для палатки (в чехле)  2000.0    Миронов
# 3       Спальник внутренний 4ка  4200.0    Кищенко
# 4                  Спальник 4ка  3800.0   Артемьев
# 5                  Спальник 2ка  1600.0      Вьяль
# 6        Печка + крышка от кана  3100.0    Лебедев
# 7             Квадрат для трубы   200.0    Лебедев
# 8                 Каны с трубой  2900.0      Ляшун
# 9                   Сухой спирт   120.0    Ткачева
# 10                     Половник    50.0      Ляшун
# 11                      Мочалка    20.0      Ляшун
# 12                        Веник   170.0    Ткачева
# 13                    Лопата №1   490.0      Ляшун
# 14                     Топор №1  1100.0    Шичанин
# 15               Пила двуручная  1120.0    Шичанин
# 16                Пила лучковая   800.0    Миронов
# 17                 Термос №1 1л  1100.0    Лебедев
# 18                 Термос N2 1л  1100.0  Лаврищева
# 19              Термос N3 1.25л  1100.0      Ляшун
# 20              Термос N4 1.25л  1100.0    Миронов
# 21              Термос N5 1.25л  1100.0   Артемьев
# 22                     Ремнабор  2500.0      Вьяль
# 23                       Аптека  1500.0      Вьяль
# 24                         GPS1   100.0    Лебедев
# 25           4 батареек для GPS   100.0    Лебедев
# 26             Карты, документы   200.0      Вьяль
# 27                    Планшетка   280.0      Вьяль
# 28                       Компас    30.0      Вьяль
# 29                Часы наручные    30.0      Вьяль
# 30  Веревка(шнурок) (D=4мм) 50м   500.0    Ткачева

# %% [markdown]
# ### Распределение снаряжения

# %%
U.print_grouped_by_members(stuff_table, fname='stuff.txt')
# Out:
# Участник: Артемьев, несет: 4900.0
#           equipment  weight Кто несет
# 4      Спальник 4ка  3800.0  Артемьев
# 21  Термос N5 1.25л  1100.0  Артемьев
#
#
#
# Участник: Вьяль, несет: 6140.0
#            equipment  weight Кто несет
# 5       Спальник 2ка  1600.0     Вьяль
# 22          Ремнабор  2500.0     Вьяль
# 23            Аптека  1500.0     Вьяль
# 26  Карты, документы   200.0     Вьяль
# 27         Планшетка   280.0     Вьяль
# 28            Компас    30.0     Вьяль
# 29     Часы наручные    30.0     Вьяль
#
#
#
# Участник: Кищенко, несет: 4200.0
#                  equipment  weight Кто несет
# 3  Спальник внутренний 4ка  4200.0   Кищенко
#
#
#
# Участник: Лаврищева, несет: 1100.0
#        equipment  weight  Кто несет
# 18  Термос N2 1л  1100.0  Лаврищева
#
#
#
# Участник: Лебедев, несет: 4600.0
#                  equipment  weight Кто несет
# 6   Печка + крышка от кана  3100.0   Лебедев
# 7        Квадрат для трубы   200.0   Лебедев
# 17            Термос №1 1л  1100.0   Лебедев
# 24                    GPS1   100.0   Лебедев
# 25      4 батареек для GPS   100.0   Лебедев
#
#
#
# Участник: Ляшун, несет: 4560.0
#           equipment  weight Кто несет
# 8     Каны с трубой  2900.0     Ляшун
# 10         Половник    50.0     Ляшун
# 11          Мочалка    20.0     Ляшун
# 13        Лопата №1   490.0     Ляшун
# 19  Термос N3 1.25л  1100.0     Ляшун
#
#
#
# Участник: Миронов, несет: 3900.0
#                      equipment  weight Кто несет
# 2   Тент для палатки (в чехле)  2000.0   Миронов
# 16               Пила лучковая   800.0   Миронов
# 20             Термос N4 1.25л  1100.0   Миронов
#
#
#
# Участник: Пименов, несет: 7500.0
#            equipment  weight Кто несет
# 0  Палатка (в чехле)  7500.0   Пименов
#
#
#
# Участник: Ткачева, несет: 990.0
#                       equipment  weight Кто несет
# 1              Подставка под ЦК   200.0   Ткачева
# 9                   Сухой спирт   120.0   Ткачева
# 12                        Веник   170.0   Ткачева
# 30  Веревка(шнурок) (D=4мм) 50м   500.0   Ткачева
#
#
#
# Участник: Шичанин, несет: 2220.0
#          equipment  weight Кто несет
# 14        Топор №1  1100.0   Шичанин
# 15  Пила двуручная  1120.0   Шичанин

# %% [markdown]
# # Общий баланс веса

# %%
import numpy as np
avg_men_weight = np.mean([m.food_weight() + m.equipment_weight() for m in Members.values() if m.male])

# %%
U.print_overweight(Members, lambda m: m.food_weight() + m.equipment_weight(), 
                   avg_men_weight, 
                   WomanFoodWeightNorm + WomanSharedEquipWeightNorm );
# Out:
# *** Перевес:
# Пименов       7500 -405
# Шичанин       8310 405
# Вьяль         8140 235
# Ткачева       2800 -200
# Кищенко       7750 -155
# Лаврищева     2900 -100
# Ляшун         7840 -65
# Артемьев      7950 45
# Миронов       7860 -45
# Лебедев       7890 -15

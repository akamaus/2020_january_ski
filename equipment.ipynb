# %%
# %load_ext autoreload
# %autoreload 2

# %%
from planner.equipment import *
# Out:
# ['Артемьев', 'Вьяль', 'Карпова', 'Кищенко', 'Лаврищева', 'Лебедев', 'Ляшун', 'Миронов', 'Пименов', 'Ткачева', 'Шичанин']
# Количество участников: 11
# Среди них женщин: 3

# %%
from members import *
import stuff as S

# %% [markdown]
# # Задача перечислить и распределить ресурсы

# %%
table = equipment_planning(S.SharedEquipment); table
# Out:
# Общий вес: 36140
# Средний вес на мужчину: 4330
# Средний вес на женщину: 500
#
#
# Перевес:
# Ляшун -3840
# Вьяль 3770
# Шичанин 3170
# Артемьев -2730
# Миронов -2330
# Пименов 1660
# Карпова -1000
# Ткачева -1000
# Лаврищева 500
# Лебедев 430
# Кищенко -130
#
# Остаток: 0
#                       equipment  weight  Кто несет
# 0             Палатка (в чехле)  7500.0    Шичанин
# 1    Тент для палатки (в чехле)  2000.0    Миронов
# 2       Спальник внутренний 4ка  4200.0    Кищенко
# 3                  Спальник 4ка  3800.0    Пименов
# 4        Печка + крышка от кана  3100.0    Лебедев
# 5             Квадрат для трубы   200.0    Лебедев
# 6                 Каны с трубой  2900.0      Вьяль
# 7                    Орг стекло   200.0      Вьяль
# 8                      Половник    50.0      Вьяль
# 9                       Мочалка    20.0      Вьяль
# 10                        Веник   170.0    Пименов
# 11                    Лопата №1   490.0      Ляшун
# ...

# %%
group_by_members(table)
# Out:
# Участник: Артемьев, несет: 1600.0
#             equipment  weight Кто несет
# 26  Веревка D=0.8 30м  1600.0  Артемьев
#
#
#
# Участник: Вьяль, несет: 8100.0
#                       equipment  weight Кто несет
# 6                 Каны с трубой  2900.0     Вьяль
# 7                    Орг стекло   200.0     Вьяль
# 8                      Половник    50.0     Вьяль
# 9                       Мочалка    20.0     Вьяль
# 12                     Топор №1  1100.0     Вьяль
# 14                Пила лучковая   800.0     Вьяль
# 17                     Ремнабор  2500.0     Вьяль
# 25                Часы наручные    30.0     Вьяль
# 27  Веревка(шнурок) (D=4мм) 50м   500.0     Вьяль
#
#
#
# Участник: Кищенко, несет: 4200.0
#                  equipment  weight Кто несет
# 2  Спальник внутренний 4ка  4200.0   Кищенко
#
#
#
# Участник: Лаврищева, несет: 1500.0
#    equipment  weight  Кто несет
# 18    Аптека  1500.0  Лаврищева
#
#
#
# Участник: Лебедев, несет: 4760.0
# ...
